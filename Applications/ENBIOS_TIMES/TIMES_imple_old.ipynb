# %% [markdown]
# # Integration TIMES-ENBIOS
#
# This jupyter notebook shows an example of the integration between [Times](https://iea-etsap.org/index.php/etsap-tools/model-generators/times) outputs and environmental analysis using [ENBIOS](https://github.com/LIVENlab/enbios).
#
# We will use [Sparks](https://github.com/LIVENlab/Sparks) to soft-link both models.

# %% [markdown]
# ## Create virtual environment -  You only need to do this once
# We will start by creating a new environment, updating pip and then installing the requirements. You can create a new enviornment in PyCharm from the bottom right corner. In this case, we will use python 3.12.
#
# Once that we have the environment installed, we will update pip and install the requirements. Then you need to reset the kernel.
#
# To update pip, you can use the following command in the terminal:
# python.exe -m pip install --upgrade pip
#
# Then you can run the following command to install the requirements:

# %%
pip install -r requirements.txt
# Out:
# Collecting accelerate==0.18.0 (from -r requirements.txt (line 1))
#   Using cached accelerate-0.18.0-py3-none-any.whl.metadata (16 kB)
# Collecting aiohttp==3.8.4 (from -r requirements.txt (line 2))
#   Using cached aiohttp-3.8.4.tar.gz (7.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting aiosignal==1.3.1 (from -r requirements.txt (line 3))
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting annotated-types==0.5.0 (from -r requirements.txt (line 4))
#   Using cached annotated_types-0.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting anyio==3.6.2 (from -r requirements.txt (line 5))
#   Using cached anyio-3.6.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting appdirs==1.4.4 (from -r requirements.txt (line 6))
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting argon2-cffi==21.3.0 (from -r requirements.txt (line 7))
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in c:\users\user\documents\pyprojects\enbios4times\venv\lib\site-packages (from -r requirements.txt (line 8)) (21.2.0)
# Collecting arrow==1.2.3 (from -r requirements.txt (line 9))
#   Using cached arrow-1.2.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting asteval==0.9.31 (from -r requirements.txt (line 10))
#   Using cached asteval-0.9.31-py3-none-any.whl.metadata (2.0 kB)
# Collecting asttokens==2.2.1 (from -r requirements.txt (line 11))
#   Using cached asttokens-2.2.1-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting astunparse==1.6.3 (from -r requirements.txt (line 12))
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting async-lru==2.0.4 (from -r requirements.txt (line 13))
#   Using cached async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting async-timeout==4.0.2 (from -r requirements.txt (line 14))
#   Using cached async_timeout-4.0.2-py3-none-any.whl.metadata (4.2 kB)
# Collecting attrs==23.1.0 (from -r requirements.txt (line 15))
#   Using cached attrs-23.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting Babel==2.13.1 (from -r requirements.txt (line 16))
#   Using cached Babel-2.13.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting backcall==0.2.0 (from -r requirements.txt (line 17))
#   Using cached backcall-0.2.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting beautifulsoup4==4.12.2 (from -r requirements.txt (line 18))
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting black==23.12.1 (from -r requirements.txt (line 19))
#   Using cached black-23.12.1-cp312-cp312-win_amd64.whl.metadata (68 kB)
# Collecting bleach==6.0.0 (from -r requirements.txt (line 20))
#   Using cached bleach-6.0.0-py3-none-any.whl.metadata (29 kB)
# Collecting blosc==1.11.1 (from -r requirements.txt (line 21))
#   Using cached blosc-1.11.1.tar.gz (1.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting boltons==23.0.0 (from -r requirements.txt (line 22))
#   Using cached boltons-23.0.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting brightway25==1.0.6 (from -r requirements.txt (line 23))
#   Using cached brightway25-1.0.6.tar.gz (12.0 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting bw-migrations==0.2 (from -r requirements.txt (line 24))
#   Using cached bw_migrations-0.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting bw-processing==0.8.3 (from -r requirements.txt (line 25))
#   Using cached bw_processing-0.8.3-py3-none-any.whl.metadata (16 kB)
# Collecting bw2analyzer==0.11.5 (from -r requirements.txt (line 26))
#   Using cached bw2analyzer-0.11.5.tar.gz (38 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting bw2calc==2.0.dev13 (from -r requirements.txt (line 27))
#   Using cached bw2calc-2.0.dev13.tar.gz (84 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting bw2data==4.0.dev19 (from -r requirements.txt (line 28))
#   Using cached bw2data-4.0.dev19.tar.gz (186 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting bw2io==0.9.dev19 (from -r requirements.txt (line 29))
#   Using cached bw2io-0.9.dev19.tar.gz (27.9 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting bw2parameters==1.1.0 (from -r requirements.txt (line 30))
#   Using cached bw2parameters-1.1.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting cattrs==22.2.0 (from -r requirements.txt (line 31))
#   Using cached cattrs-22.2.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting certifi==2023.7.22 (from -r requirements.txt (line 32))
#   Using cached certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi==1.17.1 in c:\users\user\documents\pyprojects\enbios4times\venv\lib\site-packages (from -r requirements.txt (line 33)) (1.17.1)
# Collecting chardet==5.1.0 (from -r requirements.txt (line 34))
#   Using cached chardet-5.1.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting charset-normalizer==3.2.0 (from -r requirements.txt (line 35))
#   Using cached charset_normalizer-3.2.0-py3-none-any.whl.metadata (31 kB)
# Collecting click==8.1.3 (from -r requirements.txt (line 36))
#   Using cached click-8.1.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting cloudpickle==2.2.1 (from -r requirements.txt (line 37))
#   Using cached cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting cmake==3.27.7 (from -r requirements.txt (line 38))
#   Using cached cmake-3.27.7-py2.py3-none-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: colorama==0.4.6 in c:\users\user\documents\pyprojects\enbios4times\venv\lib\site-packages (from -r requirements.txt (line 39)) (0.4.6)
# Collecting comm==0.1.3 (from -r requirements.txt (line 40))
#   Using cached comm-0.1.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting commonmark==0.9.1 (from -r requirements.txt (line 41))
#   Using cached commonmark-0.9.1-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting contourpy (from -r requirements.txt (line 42))
#   Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting coverage==7.2.5 (from -r requirements.txt (line 43))
#   Using cached coverage-7.2.5.tar.gz (759 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting cycler==0.11.0 (from -r requirements.txt (line 44))
#   Using cached cycler-0.11.0-py3-none-any.whl.metadata (785 bytes)
# Collecting databind==4.5.2 (from -r requirements.txt (line 45))
#   Using cached databind-4.5.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting databind.core==4.5.2 (from -r requirements.txt (line 46))
#   Using cached databind.core-4.5.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting databind.json==4.5.2 (from -r requirements.txt (line 47))
#   Using cached databind.json-4.5.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting datasets==2.11.0 (from -r requirements.txt (line 48))
#   Using cached datasets-2.11.0-py3-none-any.whl.metadata (20 kB)
# Collecting debugpy==1.6.7 (from -r requirements.txt (line 49))
#   Using cached debugpy-1.6.7-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting decorator==5.1.1 (from -r requirements.txt (line 50))
#   Using cached decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: defusedxml==0.7.1 in c:\users\user\documents\pyprojects\enbios4times\venv\lib\site-packages (from -r requirements.txt (line 51)) (0.7.1)
# Collecting Deprecated==1.2.14 (from -r requirements.txt (line 52))
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting dill==0.3.6 (from -r requirements.txt (line 53))
#   Using cached dill-0.3.6-py3-none-any.whl.metadata (9.8 kB)
# Collecting docopt==0.6.2 (from -r requirements.txt (line 54))
#   Using cached docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting docspec==2.2.1 (from -r requirements.txt (line 55))
#   Using cached docspec-2.2.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting docspec-python==2.2.1 (from -r requirements.txt (line 56))
#   Using cached docspec_python-2.2.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting docstring_parser==0.11 (from -r requirements.txt (line 57))
#   Using cached docstring_parser-0.11.tar.gz (22 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting docutils (from -r requirements.txt (line 58))
#   Using cached docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting enbios==2.2.11 (from -r requirements.txt (line 59))
#   Downloading enbios-2.2.11-py3-none-any.whl.metadata (14 kB)
# Collecting et-xmlfile==1.1.0 (from -r requirements.txt (line 60))
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting exceptiongroup==1.1.1 (from -r requirements.txt (line 61))
#   Downloading exceptiongroup-1.1.1-py3-none-any.whl.metadata (6.1 kB)
# Collecting executing==1.2.0 (from -r requirements.txt (line 62))
#   Downloading executing-1.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting face==20.1.1 (from -r requirements.txt (line 63))
#   Downloading face-20.1.1-py3-none-any.whl.metadata (868 bytes)
# Collecting fasteners==0.18 (from -r requirements.txt (line 64))
#   Downloading fasteners-0.18-py3-none-any.whl.metadata (4.9 kB)
# Collecting fastjsonschema==2.16.3 (from -r requirements.txt (line 65))
#   Downloading fastjsonschema-2.16.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting filelock==3.12.0 (from -r requirements.txt (line 66))
#   Downloading filelock-3.12.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting fire==0.5.0 (from -r requirements.txt (line 67))
#   Downloading fire-0.5.0.tar.gz (88 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting flatten-dict==0.4.2 (from -r requirements.txt (line 68))
#   Downloading flatten_dict-0.4.2-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting fonttools==4.47.2 (from -r requirements.txt (line 69))
#   Downloading fonttools-4.47.2-cp312-cp312-win_amd64.whl.metadata (160 kB)
# Requirement already satisfied: fqdn==1.5.1 in c:\users\user\documents\pyprojects\enbios4times\venv\lib\site-packages (from -r requirements.txt (line 70)) (1.5.1)
# Collecting frictionless==5.17.0 (from -r requirements.txt (line 71))
#   Downloading frictionless-5.17.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting friendly-data==0.3.3 (from -r requirements.txt (line 72))
#   Downloading friendly_data-0.3.3-py3-none-any.whl.metadata (3.1 kB)
# Collecting friendly-data-registry==20220103 (from -r requirements.txt (line 73))
#   Downloading friendly_data_registry-20220103-py3-none-any.whl.metadata (299 bytes)
# Collecting frozenlist==1.3.3 (from -r requirements.txt (line 74))
#   Downloading frozenlist-1.3.3.tar.gz (66 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting fs==2.4.16 (from -r requirements.txt (line 75))
#   Downloading fs-2.4.16-py2.py3-none-any.whl.metadata (6.3 kB)
# Collecting fsspec==2023.5.0 (from -r requirements.txt (line 76))
#   Downloading fsspec-2023.5.0-py3-none-any.whl.metadata (6.7 kB)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Ignored the following versions that require a different python version: 2.2.10 Requires-Python <3.12,>=3.9; 2.2.8 Requires-Python <3.12,>=3.9; 2.2.9 Requires-Python <3.12,>=3.9; 3.0.0 Requires-Python >=3.7, <=3.11; 3.0.1 Requires-Python >=3.7, <3.12
# ERROR: Could not find a version that satisfies the requirement geojson==3.0.1 (from versions: 1.0a3, 1.0b1, 1.0rc1, 1.0, 1.0.1, 1.0.4, 1.0.5, 1.0.6, 1.0.7, 1.0.8, 1.0.9, 1.1.0, 1.2.0, 1.2.1, 1.2.2, 1.3.0, 1.3.1, 1.3.2, 1.3.3, 1.3.4, 1.3.5, 2.0.0, 2.1.0, 2.2.0, 2.3.0, 2.4.0, 2.4.1, 2.5.0, 3.1.0, 3.2.0)
# ERROR: No matching distribution found for geojson==3.0.1

# %% [markdown]
# ## Define a basefile
# The basefile will map the lifecycle inventories (LCI) to be used in [ENBIOS](https://github.com/LIVENlab/enbios), as well as the hierarchical structure to follow.
#
# In this exercice, we are going to analyze the electricity production output, distinguishing between `baseload` technologies and `intermittent`.

# %%
import pandas as pd

df = pd.read_excel(r'testing/input_data/Times_ecoinvent.xlsx')

df.head()
# Out:
#         Processor Parent_Processor TIMES PROCESS DESCRIPTION Carrier  \
# 0     CHPAGRBGS00         Baseload            CHP.AGR.BGS.00  ELCHIG
# 1     CHPAGRBGS00         Baseload            CHP.AGR.BGS.00    HEAT
# 2  CHPAGRBGSREP01         Baseload        CHP.AGR.BGS.REP.01  ELCHIG
# 3  CHPAGRBGSREP01         Baseload        CHP.AGR.BGS.REP.01    HEAT
# 4     CHPAGRBIO00         Baseload            CHP.AGR.BIO.00  ELCHIG
#
#   TIMES Unit  TIMESToEcoinventFactor  \
# 0         PJ            277800000000
# 1         PJ              1000000000
# 2         PJ            277800000000
# 3         PJ              1000000000
# 4         PJ            277800000000
#
#                                 EcoinventCarrierName  \
# 0                          electricity, high voltage
# 1  heat, central or small-scale, other than natur...
# 2                          electricity, high voltage
# 3  heat, central or small-scale, other than natur...
# 4                          electricity, high voltage
#
#                                   Ecoinvent Activity Ecoinvent Location  \
# 0   heat and power co-generation, biogas, gas engine                 ES
# 1   heat and power co-generation, biogas, gas engine                 ES
# 2   heat and power co-generation, biogas, gas engine                 ES
# 3   heat and power co-generation, biogas, gas engine                 ES
# 4  heat and power co-generation, wood chips, 6667...                 ES
#
#   Ecoinvent unit                                               ISIC  \
# 0  kilowatt hour  3821:Treatment and disposal of non-hazardous w...
# 1      megajoule  3821:Treatment and disposal of non-hazardous w...
# 2  kilowatt hour  3821:Treatment and disposal of non-hazardous w...
# 3      megajoule  3821:Treatment and disposal of non-hazardous w...
# 4  kilowatt hour             3530:Steam and air conditioning supply
#
#                                   Ecoinvent_key_code        Factor Comments   \
# 0  ('ei36_cutoff_IMAGE_SSP2_SS', '4de25bf8baf97e6...  2.777778e+08       NaN
# 1  ('ei36_cutoff_IMAGE_SSP2_SS', '6defc436144d3d5...  1.000000e+09       NaN
# 2  ('ei36_cutoff_IMAGE_SSP2_SS', '4de25bf8baf97e6...  2.777778e+08       NaN
# 3  ('ei36_cutoff_IMAGE_SSP2_SS', '6defc436144d3d5...  1.000000e+09       NaN
# 4  ('ei36_cutoff_IMAGE_SSP2_SS', 'cc7b47e491ad9fc...  2.777778e+08       NaN
#
#   Unnamed: 14
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# ## Sparks
# Sparks helps to soft-link the energy system data with ENBIOS, following the instructions defined on the basefile.
# Define the path to the `basefile`, `energy data` (TIMES outputs'), along with a `Brightway project` and `Database`. It will also adapt the units to match TIMES and Ecoinvent data.

# %%
from Sparks.util.base import SoftLink
import bw2data as bd

enbios_mod = SoftLink(r'testing\data_test\ElectricgenerationTIMES-Sinergia.xlsx',
                      r'testing\data_test\Times_ecoinvent.xlsx',
                       'Seeds_exp4',
                      'db_experiments')

enbios_mod.preprocess(subregions=False)
# Out:
# Project and Database existing...
# Adapting input data...
# C:\Users\altz7\PycharmProjects\ENBIOS4TIMES_\Sparks\util\preprocess\cleaner.py:124: Warning:
# The following technologies, are present in the energy data but not in the Basefile:
#
# {'CHPGENRES00', 'EUGTBGS00', 'EUGASCOG', 'EUGTBGS01', 'ESTBATS101', 'IMPELCHIGA', 'UPSELCHIGOL00', 'EUGTOILGAS00', 'EUCCFUELTNP00', 'EUGTBGSREPOW01', 'EUSTWOO00'}
#
#  Please,check the following items in order to avoid missing information
#   warnings.warn(message,Warning)
# C:\Users\altz7\PycharmProjects\ENBIOS4TIMES_\Sparks\generic\generic_dataclass.py:50: Warning:
# 972e398cc52b4431770c512aaa67b278_copy1 not found in the database. Please check your database / basefile.
# This activity won't be included.
#   warnings.warn(message, Warning)
# C:\Users\altz7\PycharmProjects\ENBIOS4TIMES_\Sparks\generic\generic_dataclass.py:50: Warning:
# d65e09be05273e10d350c96a37998e4b_copy1 not found in the database. Please check your database / basefile.
# This activity won't be included.
#   warnings.warn(message, Warning)
# C:\Users\altz7\PycharmProjects\ENBIOS4TIMES_\Sparks\generic\generic_dataclass.py:50: Warning:
# 9278f7035907ffd4557ad866f30ce8c3 not found in the database. Please check your database / basefile.
# This activity won't be included.
#   warnings.warn(message, Warning)
# function preprocess executed in 0.25455260276794434 seconds

# %% [markdown]
# Sparks will notify missing technologies in the basefile, as well as possible problems in the definition of the database.
# Check the excluded technologies with the following example

# %%
enbios_mod.exluded_techs_and_regions
# Out:
# {'CHPGENRES00',
#  'ESTBATS101',
#  'EUCCFUELTNP00',
#  'EUGASCOG',
#  'EUGTBGS00',
#  'EUGTBGS01',
#  'EUGTBGSREPOW01',
#  'EUGTOILGAS00',
#  'EUSTWOO00',
#  'IMPELCHIGA',
#  'UPSELCHIGOL00'}

# %% [markdown]
# You can also check the conversion process

# %%
enbios_mod.preprocessed_units
# Out:
#    Commodity             Process   scenarios  flow_out_sum  \
# 0     ELCHIG         CHPAGRBGS00  def_hydro1      0.162997
# 1     ELCHIG      CHPAGRBGSREP01  def_hydro1      0.189641
# 2     ELCHIG         CHPAGRBIO00  def_hydro1      0.012481
# 3     ELCHIG      CHPAGRBIOREP01  def_hydro1      0.014521
# 4     ELCHIG         CHPAGRGAS00  def_hydro1     21.522390
# ..       ...                 ...         ...           ...
# 67    ELCHIG          EUWINOF201  def_hydro1    181.570416
# 68    ELCHIG     EUWINOFREPOW201  def_hydro1      4.040089
# 69    ELCHIG          EUWINON201  def_hydro1    703.337998
# 70    ELCHIG          EUWINON501  def_hydro1   1023.605741
# 71    ELCHIG  EUWINONREPEXIST101  def_hydro1    550.987432
#
#                 alias_carrier  flow_out_sum_      new_units  \
# 0          CHPAGRBGS00_ELCHIG   4.528060e+10  kilowatt hour
# 1       CHPAGRBGSREP01_ELCHIG   5.268224e+10  kilowatt hour
# 2          CHPAGRBIO00_ELCHIG   3.467138e+09  kilowatt hour
# 3       CHPAGRBIOREP01_ELCHIG   4.033882e+09  kilowatt hour
# 4          CHPAGRGAS00_ELCHIG   5.978920e+12  kilowatt hour
# ..                        ...            ...            ...
# 67          EUWINOF201_ELCHIG   5.044026e+13  kilowatt hour
# 68     EUWINOFREPOW201_ELCHIG   1.122337e+12  kilowatt hour
# 69          EUWINON201_ELCHIG   1.953873e+14  kilowatt hour
# 70          EUWINON501_ELCHIG   2.843577e+14  kilowatt hour
# 71  EUWINONREPEXIST101_ELCHIG   1.530643e+14  kilowatt hour
#
#                        aliases
# 0          CHPAGRBGS00__ELCHIG
# 1       CHPAGRBGSREP01__ELCHIG
# 2          CHPAGRBIO00__ELCHIG
# 3       CHPAGRBIOREP01__ELCHIG
# 4          CHPAGRGAS00__ELCHIG
# ..                         ...
# 67          EUWINOF201__ELCHIG
# 68     EUWINOFREPOW201__ELCHIG
# 69          EUWINON201__ELCHIG
# 70          EUWINON501__ELCHIG
# 71  EUWINONREPEXIST101__ELCHIG
#
# [61 rows x 8 columns]

# %%
enbios_mod.data_for_ENBIOS(smaller_vers=True,
                           path_save=r'test2.json')
# Out:
# Input data for ENBIOS created

# %%
enbios_mod.enbios2_data
# Out:
# {'adapters': [{'adapter_name': 'brightway-adapter',
#    'config': {'bw_project': 'Seeds_exp4'},
#    'methods': {'GWP1000': ['ReCiPe 2016 v1.03, midpoint (H)',
#      'climate change',
#      'global warming potential (GWP1000)'],
#     'LOP': ['ReCiPe 2016 v1.03, midpoint (H)',
#      'land use',
#      'agricultural land occupation (LOP)'],
#     'WCP': ['ReCiPe 2016 v1.03, midpoint (H)',
#      'water use',
#      'water consumption potential (WCP)'],
#     'FEP': ['ReCiPe 2016 v1.03, midpoint (H)',
#      'eutrophication: freshwater',
#      'freshwater eutrophication potential (FEP)'],
#     'SOP': ['ReCiPe 2016 v1.03, midpoint (H)',
#      'material resources: metals/minerals',
#      'surplus ore potential (SOP)']}}],
#  'hierarchy': {'name': 'Energysystem',
#   'aggregator': 'sum',
#   'children': [{'name': 'Generation',
#     'aggregator': 'sum',
#     'children': [{'name': 'Baseload',
#       'aggregator': 'sum',
#       'children': [{'name': 'CHPAGRBGS00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '4de25bf8baf97e6cdaf2b4d4721a71a4'}},
#        {'name': 'CHPAGRBGSREP01__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '4de25bf8baf97e6cdaf2b4d4721a71a4'}},
#        {'name': 'CHPAGRBIO00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'cc7b47e491ad9fc3bda416c2571e741c'}},
#        {'name': 'CHPAGRBIOREP01__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'cc7b47e491ad9fc3bda416c2571e741c'}},
#        {'name': 'CHPAGRGAS00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '9c5387df72e4d6bde29bfbd7cf2646d5'}},
#        {'name': 'CHPAGRHFO00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'e084d924262e8dd033e90b2b99c944b2'}},
#        {'name': 'CHPCOMBGS00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '4de25bf8baf97e6cdaf2b4d4721a71a4'}},
#        {'name': 'CHPCOMBGSREP01__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '4de25bf8baf97e6cdaf2b4d4721a71a4'}},
#        {'name': 'CHPCOMGAS00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '9c5387df72e4d6bde29bfbd7cf2646d5'}},
#        {'name': 'CHPCOMMAR00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'e084d924262e8dd033e90b2b99c944b2'}},
#        {'name': 'CHPCOMOIL00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'e084d924262e8dd033e90b2b99c944b2'}},
#        {'name': 'CHPCOMRSU00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '457a9cb15fd86328b0109ec4216b1632'}},
#        {'name': 'CHPGENBGS00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '4de25bf8baf97e6cdaf2b4d4721a71a4'}},
#        {'name': 'CHPGENBGSREP01__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '4de25bf8baf97e6cdaf2b4d4721a71a4'}},
#        {'name': 'CHPGENBIO00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'cc7b47e491ad9fc3bda416c2571e741c'}},
#        {'name': 'CHPGENGASCC00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '9c5387df72e4d6bde29bfbd7cf2646d5'}},
#        {'name': 'CHPGENGASCCREF00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '9c5387df72e4d6bde29bfbd7cf2646d5'}},
#        {'name': 'CHPGENGASCCREF01__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '9c5387df72e4d6bde29bfbd7cf2646d5'}},
#        {'name': 'CHPGENGASCCREP01__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '9c5387df72e4d6bde29bfbd7cf2646d5'}},
#        {'name': 'CHPGENGASCI00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '9c5387df72e4d6bde29bfbd7cf2646d5'}},
#        {'name': 'CHPGENGASCIREP01__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '9c5387df72e4d6bde29bfbd7cf2646d5'}},
#        {'name': 'CHPGENGASOLI00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '9c5387df72e4d6bde29bfbd7cf2646d5'}},
#        {'name': 'CHPGENGASPUR00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '9c5387df72e4d6bde29bfbd7cf2646d5'}},
#        {'name': 'CHPGENOIL00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'e084d924262e8dd033e90b2b99c944b2'}},
#        {'name': 'CHPGENRFG00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '9c5387df72e4d6bde29bfbd7cf2646d5'}},
#        {'name': 'CHPGENSOLID00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '0c57a97749f03a9386ba7027eb4247f9'}},
#        {'name': 'CHPRSDGAS00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '9c5387df72e4d6bde29bfbd7cf2646d5'}},
#        {'name': 'ENUC_TOTAL__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '0919171fc84f3dd3ed892700571f313b'}},
#        {'name': 'EUCCGAS00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '354ca675167e3a9001d25391973f0289'}},
#        {'name': 'EUGEOFLS101__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'd08b00b0e0faa4245cd2d5b7398867ef'}},
#        {'name': 'EUHYD10_50MW__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '3021d25fd47ef22859c41df46d489a14'}},
#        {'name': 'EUHYD10_50MW101__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '3021d25fd47ef22859c41df46d489a14'}},
#        {'name': 'EUHYDM50MW_OL__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'efae6a026882b2111c41f39db1d9fb13'}},
#        {'name': 'EUHYDPSCL__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'efae6a026882b2111c41f39db1d9fb13'}},
#        {'name': 'EUHYDPSCL01__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'efae6a026882b2111c41f39db1d9fb13'}},
#        {'name': 'EUICOIL00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '8512aa7eb21d45b94590bb09716506b8'}},
#        {'name': 'EUIPCOH00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'cfa79d34d94d122a4fd35786da2c6d4e'}},
#        {'name': 'EUNPCOH00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'cfa79d34d94d122a4fd35786da2c6d4e'}},
#        {'name': 'EUNPCOLCOH00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '068842db6eef205f8d27b326e7e55a0c'}}]},
#      {'name': 'Intermittent',
#       'aggregator': 'sum',
#       'children': [{'name': 'EUHYD1_10MW__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '3f9af15db6e86e39021de2d013bf26d3'}},
#        {'name': 'EUHYD1_10MW101__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '3f9af15db6e86e39021de2d013bf26d3'}},
#        {'name': 'EUHYDL1MW__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '3f9af15db6e86e39021de2d013bf26d3'}},
#        {'name': 'EUPVSOL00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '46ec4bc016881dafa23a3bbc4c11a7e4'}},
#        {'name': 'EUPVSOL101__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '46ec4bc016881dafa23a3bbc4c11a7e4'}},
#        {'name': 'EUPVSOLAUTOCAGR101__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '46ec4bc016881dafa23a3bbc4c11a7e4'}},
#        {'name': 'EUPVSOLAUTOCCOM101__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '8b0ca7f94a5fc4975be65b4026151bc0'}},
#        {'name': 'EUPVSOLAUTOCIND101__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '8b0ca7f94a5fc4975be65b4026151bc0'}},
#        {'name': 'EUPVSOLAUTOCRSD101__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '8b0ca7f94a5fc4975be65b4026151bc0'}},
#        {'name': 'EUPVSOLREPOW101__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '46ec4bc016881dafa23a3bbc4c11a7e4'}},
#        {'name': 'EUSTMUN00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '457a9cb15fd86328b0109ec4216b1632'}},
#        {'name': 'EUSTOIL00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '8512aa7eb21d45b94590bb09716506b8'}},
#        {'name': 'EUTHSOL00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '19040cdacdbf038e2f6ad59814f7a9ed'}},
#        {'name': 'EUTHSOLREPOW101__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '19040cdacdbf038e2f6ad59814f7a9ed'}},
#        {'name': 'EUTHSOLSTG101__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '19040cdacdbf038e2f6ad59814f7a9ed'}},
#        {'name': 'EUTHSOLSTGREPOW101__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '19040cdacdbf038e2f6ad59814f7a9ed'}},
#        {'name': 'EUWIN00__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'ed3da88fc23311ee183e9ffd376de89b'}},
#        {'name': 'EUWINOF201__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '6ebfe52dc3ef5b4d35bb603b03559023'}},
#        {'name': 'EUWINOFREPOW201__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '6ebfe52dc3ef5b4d35bb603b03559023'}},
#        {'name': 'EUWINON201__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '0d48975a3766c13e68cedeb6c24f6f74'}},
#        {'name': 'EUWINON501__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': '0d48975a3766c13e68cedeb6c24f6f74'}},
#        {'name': 'EUWINONREPEXIST101__ELCHIG',
#         'adapter': 'bw',
#         'config': {'code': 'ed3da88fc23311ee183e9ffd376de89b'}}]}]}]},
#  'scenarios': [{'name': 'def_hydro1',
#    'nodes': {'CHPAGRBGS00__ELCHIG': ['kilowatt hour', 45280604558.59206],
#     'CHPAGRBGSREP01__ELCHIG': ['kilowatt hour', 52682241842.20799],
#     'CHPAGRBIO00__ELCHIG': ['kilowatt hour', 3467138148.8639994],
#     'CHPAGRBIOREP01__ELCHIG': ['kilowatt hour', 4033881884.736006],
#     'CHPAGRGAS00__ELCHIG': ['kilowatt hour', 5978919814523.137],
#     'CHPAGRHFO00__ELCHIG': ['kilowatt hour', 1219069037721.6],
#     'CHPCOMBGS00__ELCHIG': ['kilowatt hour', 262668102967.29605],
#     'CHPCOMBGSREP01__ELCHIG': ['kilowatt hour', 305604235183.104],
#     'CHPCOMGAS00__ELCHIG': ['kilowatt hour', 3121734173156.352],
#     'CHPCOMMAR00__ELCHIG': ['kilowatt hour', 108867588710.39998],
#     'CHPCOMOIL00__ELCHIG': ['kilowatt hour', 47906148985.344],
#     'CHPCOMRSU00__ELCHIG': ['kilowatt hour', 794405147328.0001],
#     'CHPGENBGS00__ELCHIG': ['kilowatt hour', 166946408076.53986],
#     'CHPGENBGSREP01__ELCHIG': ['kilowatt hour', 21411050889.689747],
#     'CHPGENBIO00__ELCHIG': ['kilowatt hour', 3584796324719.4995],
#     'CHPGENGASCC00__ELCHIG': ['kilowatt hour', 46698484944529.5],
#     'CHPGENGASCCREF00__ELCHIG': ['kilowatt hour', 22374336700780.41],
#     'CHPGENGASCCREF01__ELCHIG': ['kilowatt hour', 14390403640241.426],
#     'CHPGENGASCCREP01__ELCHIG': ['kilowatt hour', 5021887258026.341],
#     'CHPGENGASCI00__ELCHIG': ['kilowatt hour', 17311681273300.168],
#     'CHPGENGASCIREP01__ELCHIG': ['kilowatt hour', 3390445977249.067],
#     'CHPGENGASOLI00__ELCHIG': ['kilowatt hour', 7320601100429.857],
#     'CHPGENGASPUR00__ELCHIG': ['kilowatt hour', 2358115031433.3784],
#     'CHPGENOIL00__ELCHIG': ['kilowatt hour', 9477088108850.176],
#     'CHPGENRFG00__ELCHIG': ['kilowatt hour', 114351511110.60002],
#     'CHPGENSOLID00__ELCHIG': ['kilowatt hour', 453811757563.2322],
#     'CHPRSDGAS00__ELCHIG': ['kilowatt hour', 101522063515.392],
#     'ENUC_TOTAL__ELCHIG': ['kilowatt hour', 255719577220261.66],
#     'EUCCGAS00__ELCHIG': ['kilowatt hour', 226520275749098.3],
#     'EUGEOFLS101__ELCHIG': ['kilowatt hour', 375029999999.99915],
#     'EUHYD1_10MW__ELCHIG': ['kilowatt hour', 26536644764418.934],
#     'EUHYD1_10MW101__ELCHIG': ['kilowatt hour', 3756102279490.611],
#     'EUHYD10_50MW__ELCHIG': ['kilowatt hour', 115977260692265.0],
#     'EUHYD10_50MW101__ELCHIG': ['kilowatt hour', 3729429947462.932],
#     'EUHYDL1MW__ELCHIG': ['kilowatt hour', 4290196086836.5107],
#     'EUHYDM50MW_OL__ELCHIG': ['kilowatt hour', 102610601447185.17],
#     'EUHYDPSCL__ELCHIG': ['kilowatt hour', 35544373044316.35],
#     'EUHYDPSCL01__ELCHIG': ['kilowatt hour', 26652673853043.527],
#     'EUICOIL00__ELCHIG': ['kilowatt hour', 18654385563072.66],
#     'EUIPCOH00__ELCHIG': ['kilowatt hour', 86760663861603.27],
#     'EUNPCOH00__ELCHIG': ['kilowatt hour', 24662641740024.086],
#     'EUNPCOLCOH00__ELCHIG': ['kilowatt hour', 3573963697860.6523],
#     'EUPVSOL00__ELCHIG': ['kilowatt hour', 51508366971217.51],
#     'EUPVSOL101__ELCHIG': ['kilowatt hour', 432672356484890.06],
#     'EUPVSOLAUTOCAGR101__ELCHIG': ['kilowatt hour', 295997289277.96295],
#     'EUPVSOLAUTOCCOM101__ELCHIG': ['kilowatt hour', 15684800199174.143],
#     'EUPVSOLAUTOCIND101__ELCHIG': ['kilowatt hour', 2125569206542.322],
#     'EUPVSOLAUTOCRSD101__ELCHIG': ['kilowatt hour', 31762151251980.797],
#     'EUPVSOLREPOW101__ELCHIG': ['kilowatt hour', 15299812775353.46],
#     'EUSTMUN00__ELCHIG': ['kilowatt hour', 3929419405598.1787],
#     'EUSTOIL00__ELCHIG': ['kilowatt hour', 13288974676024.71],
#     'EUTHSOL00__ELCHIG': ['kilowatt hour', 9365479725453.904],
#     'EUTHSOLREPOW101__ELCHIG': ['kilowatt hour', 12180621703786.559],
#     'EUTHSOLSTG101__ELCHIG': ['kilowatt hour', 78112221326881.12],
#     'EUTHSOLSTGREPOW101__ELCHIG': ['kilowatt hour', 4545728419544.8125],
#     'EUWIN00__ELCHIG': ['kilowatt hour', 175380574010788.9],
#     'EUWINOF201__ELCHIG': ['kilowatt hour', 50440261621185.734],
#     'EUWINOFREPOW201__ELCHIG': ['kilowatt hour', 1122336805198.946],
#     'EUWINON201__ELCHIG': ['kilowatt hour', 195387295740392.25],
#     'EUWINON501__ELCHIG': ['kilowatt hour', 284357674977220.56],
#     'EUWINONREPEXIST101__ELCHIG': ['kilowatt hour', 153064308667635.72]}}]}

# %% [markdown]
#  If you want to check the structure of this file, you can use the following [JSON schema](https://github.com/LIVENlab/enbios/blob/main/data/schema/experiment.schema.gen.json) and a [validator](https://www.jsonschemavalidator.net/)

# %% [markdown]
# ## Run ENBIOS
# Now that we have transformed the energy data into an ENBIOS-like format, let's run some experiments!
# Pass the `path` to the json file that generated using Sparks

# %%
import enbios as enb
import json


exp = enb.Experiment(r'test2.json')
exp.run()
# Out:
# 2025-02-26 13:33:47,843 - ............enbios.base - INFO - Running scenario 'def_hydro1'
# {'def_hydro1': {'name': 'Energysystem',
#   'results': {'GWP1000': {'unit': 'kg CO2-Eq', 'magnitude': 509803091068436.3},
#    'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 17716236708772.082},
#    'WCP': {'unit': 'cubic meter', 'magnitude': 6928428138974.544},
#    'FEP': {'unit': 'kg P-Eq', 'magnitude': 121794684385.60413},
#    'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 6970625003184.134}},
#   'output': [{'unit': 'kilowatt_hour',
#     'magnitude': 2610618292470812.0,
#     'label': None}],
#   'children': [{'name': 'Generation',
#     'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#       'magnitude': 509803091068436.3},
#      'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 17716236708772.082},
#      'WCP': {'unit': 'cubic meter', 'magnitude': 6928428138974.544},
#      'FEP': {'unit': 'kg P-Eq', 'magnitude': 121794684385.60413},
#      'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 6970625003184.134}},
#     'output': [{'unit': 'kilowatt_hour',
#       'magnitude': 2610618292470812.0,
#       'label': None}],
#     'children': [{'name': 'Baseload',
#       'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#         'magnitude': 435394365483715.56},
#        'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 4286019432061.6123},
#        'WCP': {'unit': 'cubic meter', 'magnitude': 5500814629875.917},
#        'FEP': {'unit': 'kg P-Eq', 'magnitude': 88944053792.10214},
#        'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 2192524321597.4902}},
#       'output': [{'unit': 'kilowatt_hour',
#         'magnitude': 1045511398081918.4,
#         'label': None}],
#       'children': [{'name': 'CHPAGRBGS00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 42184196170.0762},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 377244765.0592484},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 11360560.833699362},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 1880951.8087947858},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 62802937.33847955}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 45280604558.59206,
#           'label': None}],
#         'bw_activity_code': '4de25bf8baf97e6cdaf2b4d4721a71a4'},
#        {'name': 'CHPAGRBGSREP01__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 49079689774.79591},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 438909775.0515891},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 13217575.585287083},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 2188415.085240317},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 73068802.0997762}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 52682241842.20799,
#           'label': None}],
#         'bw_activity_code': '4de25bf8baf97e6cdaf2b4d4721a71a4'},
#        {'name': 'CHPAGRBIO00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 5492844642.746904},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 1370027181.408856},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 4061083.406837018},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 65541.1030136131},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 5561860.6227058815}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 3467138148.8639994,
#           'label': None}],
#         'bw_activity_code': 'cc7b47e491ad9fc3bda416c2571e741c'},
#        {'name': 'CHPAGRBIOREP01__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 6390713478.583142},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 1593973932.2227838},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 4724914.348353756},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 76254.55254704281},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 6471010.917013823}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 4033881884.736006,
#           'label': None}],
#         'bw_activity_code': 'cc7b47e491ad9fc3bda416c2571e741c'},
#        {'name': 'CHPAGRGAS00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 3591632543393.395},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 6062099310.118711},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 6681971407.75944},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 78385403.46772137},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 27377919938.92403}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 5978919814523.137,
#           'label': None}],
#         'bw_activity_code': '9c5387df72e4d6bde29bfbd7cf2646d5'},
#        {'name': 'CHPAGRHFO00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 789691768961.5052},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 1429158450.6852958},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 392578288.4439559},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 10035293.59082059},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 2535628775.1264586}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 1219069037721.6,
#           'label': None}],
#         'bw_activity_code': 'e084d924262e8dd033e90b2b99c944b2'},
#        {'name': 'CHPCOMBGS00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 244706158215.0612},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 2188357858.7137375},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 65901438.19604901},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 10911206.866687508},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 364313342.82238483}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 262668102967.29605,
#           'label': None}],
#         'bw_activity_code': '4de25bf8baf97e6cdaf2b4d4721a71a4'},
#        {'name': 'CHPCOMBGSREP01__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 284706203307.8795},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 2546070201.7810698},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 76673788.67025557},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 12694769.527585693},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 423864562.37038165}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 305604235183.104,
#           'label': None}],
#         'bw_activity_code': '4de25bf8baf97e6cdaf2b4d4721a71a4'},
#        {'name': 'CHPCOMGAS00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 1875275533969.8416},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 3165164115.177438},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 3488813888.1866555},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 40926856.36159186},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 14294653697.383057}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 3121734173156.352,
#           'label': None}],
#         'bw_activity_code': '9c5387df72e4d6bde29bfbd7cf2646d5'},
#        {'name': 'CHPCOMMAR00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 70522534853.74467},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 127629385.5681057},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 35058762.26932181},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 896190.5962446402},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 226441474.0639983}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 108867588710.39998,
#           'label': None}],
#         'bw_activity_code': 'e084d924262e8dd033e90b2b99c944b2'},
#        {'name': 'CHPCOMOIL00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 31032772027.561867},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 56162099.853640854},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 15427275.546943313},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 394360.16509271855},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 99643421.24129513}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 47906148985.344,
#           'label': None}],
#         'bw_activity_code': 'e084d924262e8dd033e90b2b99c944b2'},
#        {'name': 'CHPCOMRSU00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq', 'magnitude': 0.0},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 0.0},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 0.0},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 0.0},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 0.0}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 794405147328.0001,
#           'label': None}],
#         'bw_activity_code': '457a9cb15fd86328b0109ec4216b1632'},
#        {'name': 'CHPGENBGS00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 155530167868.46298},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 1390874948.0513163},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 41885589.7211749},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 6934937.183398583},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 231550018.10323802}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 166946408076.53986,
#           'label': None}],
#         'bw_activity_code': '4de25bf8baf97e6cdaf2b4d4721a71a4'},
#        {'name': 'CHPGENBGSREP01__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 19946906180.738945},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 178381162.20924544},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 5371870.550534874},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 889412.9239497216},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 29696531.222691257}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 21411050889.689747,
#           'label': None}],
#         'bw_activity_code': '4de25bf8baf97e6cdaf2b4d4721a71a4'},
#        {'name': 'CHPGENBIO00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 5679245660864.575},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 1416519386830.4297},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 4198897259.3549237},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 67765256.27185576},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 5750603714.230388}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 3584796324719.4995,
#           'label': None}],
#         'bw_activity_code': 'cc7b47e491ad9fc3bda416c2571e741c'},
#        {'name': 'CHPGENGASCC00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 28052525113992.1},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 47348160069.550354},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 52189684901.31076},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 612230920.7255208},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 213835846863.1992}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 46698484944529.5,
#           'label': None}],
#         'bw_activity_code': '9c5387df72e4d6bde29bfbd7cf2646d5'},
#        {'name': 'CHPGENGASCCREF00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 13440621102629.5},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 22685611239.796677},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 25005299072.792416},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 293334157.9486024},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 102453757162.00383}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 22374336700780.41,
#           'label': None}],
#         'bw_activity_code': '9c5387df72e4d6bde29bfbd7cf2646d5'},
#        {'name': 'CHPGENGASCCREF01__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 8644545107294.684},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 14590604881.169996},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 16082548130.767601},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 188662439.48344925},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 65894732020.61179}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 14390403640241.426,
#           'label': None}],
#         'bw_activity_code': '9c5387df72e4d6bde29bfbd7cf2646d5'},
#        {'name': 'CHPGENGASCCREP01__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 3016727814440.7144},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 5091752370.946653},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 5612402927.272275},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 65838424.18250004},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 22995596449.72091}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 5021887258026.341,
#           'label': None}],
#         'bw_activity_code': '9c5387df72e4d6bde29bfbd7cf2646d5'},
#        {'name': 'CHPGENGASCI00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 10399403197657.42},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 17552523388.14842},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 19347334108.95003},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 226961250.67495483},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 79271480179.37411}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 17311681273300.168,
#           'label': None}],
#         'bw_activity_code': '9c5387df72e4d6bde29bfbd7cf2646d5'},
#        {'name': 'CHPGENGASCIREP01__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 2036695002870.7512},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 3437614298.9167666},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 3789123083.1643686},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 44449747.52985168},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 15525105106.698057}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 3390445977249.067,
#           'label': None}],
#         'bw_activity_code': '9c5387df72e4d6bde29bfbd7cf2646d5'},
#        {'name': 'CHPGENGASOLI00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 4397601902184.7827},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 7422446218.394024},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 8181418844.457498},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 95975241.1587654},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 33521578651.992496}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 7320601100429.857,
#           'label': None}],
#         'bw_activity_code': '9c5387df72e4d6bde29bfbd7cf2646d5'},
#        {'name': 'CHPGENGASPUR00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 1416557329868.0474},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 2390921422.427781},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 2635401996.542863},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 30915584.088311087},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 10797984676.100245}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 2358115031433.3784,
#           'label': None}],
#         'bw_activity_code': '9c5387df72e4d6bde29bfbd7cf2646d5'},
#        {'name': 'CHPGENOIL00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 6139093227292.803},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 11110330973.133307},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 3051918236.6536756},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 78014746.0604887},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 19712072536.418568}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 9477088108850.176,
#           'label': None}],
#         'bw_activity_code': 'e084d924262e8dd033e90b2b99c944b2'},
#        {'name': 'CHPGENRFG00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 68692777530.40315},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 115942383.59672233},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 127797921.9298463},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 1499182.062840685},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 523624101.5372931}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 114351511110.60002,
#           'label': None}],
#         'bw_activity_code': '9c5387df72e4d6bde29bfbd7cf2646d5'},
#        {'name': 'CHPGENSOLID00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 542199692209.05994},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 4692436813.32872},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 316594574.77302635},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 277582592.39454883},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 1079415187.3438215}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 453811757563.2322,
#           'label': None}],
#         'bw_activity_code': '0c57a97749f03a9386ba7027eb4247f9'},
#        {'name': 'CHPRSDGAS00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 60985923626.76396},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 102934450.69350678},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 113459880.1476784},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 1330984.2150772302},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 464877103.55197555}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 101522063515.392,
#           'label': None}],
#         'bw_activity_code': '9c5387df72e4d6bde29bfbd7cf2646d5'},
#        {'name': 'ENUC_TOTAL__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 1993561584380.8628},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 74913915877.07762},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 793663930558.6309},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 1119581388.5793357},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 299564876419.32495}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 255719577220261.66,
#           'label': None}],
#         'bw_activity_code': '0919171fc84f3dd3ed892700571f313b'},
#        {'name': 'EUCCGAS00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 109590170953894.92},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 58711079480.11375},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 167576684783.20868},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 644571691.0911688},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 281262399779.10315}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 226520275749098.3,
#           'label': None}],
#         'bw_activity_code': '354ca675167e3a9001d25391973f0289'},
#        {'name': 'EUGEOFLS101__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 27332423128.575397},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 484558708.71373475},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 165557835.62309852},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 13496275.222721746},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 1668628601.7168698}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 375029999999.99915,
#           'label': None}],
#         'bw_activity_code': 'd08b00b0e0faa4245cd2d5b7398867ef'},
#        {'name': 'EUHYD10_50MW__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 6039200049878.484},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 12721595473.45325},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 3392210858204.8896},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 157350299.56632832},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 38913751816.90046}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 115977260692265.0,
#           'label': None}],
#         'bw_activity_code': '3021d25fd47ef22859c41df46d489a14'},
#        {'name': 'EUHYD10_50MW101__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 194199909450.38974},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 409082771.07459337},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 109081838001.55939},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 5059844.627693957},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 1251332464.05456}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 3729429947462.932,
#           'label': None}],
#         'bw_activity_code': '3021d25fd47ef22859c41df46d489a14'},
#        {'name': 'EUHYDM50MW_OL__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 47070735958286.92},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 899088752292.9634},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 401926206592.8183},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 7416648947.254666},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 396096116693.495}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 102610601447185.17,
#           'label': None}],
#         'bw_activity_code': 'efae6a026882b2111c41f39db1d9fb13'},
#        {'name': 'EUHYDPSCL__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 16305330782346.12},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 311444875851.264},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 139227475737.7437},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 2569131582.9154162},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 137207929147.79552}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 35544373044316.35,
#           'label': None}],
#         'bw_activity_code': 'efae6a026882b2111c41f39db1d9fb13'},
#        {'name': 'EUHYDPSCL01__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 12226426468853.688},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 233534536744.01236},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 104398648348.46814},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 1926443493.0281107},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 102884306922.75089}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 26652673853043.527,
#           'label': None}],
#         'bw_activity_code': 'efae6a026882b2111c41f39db1d9fb13'},
#        {'name': 'EUICOIL00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 17458118853644.902},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 31590451097.839863},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 23868816347.787224},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 221797771.31238937},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 56037020331.811646}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 18654385563072.66,
#           'label': None}],
#         'bw_activity_code': '8512aa7eb21d45b94590bb09716506b8'},
#        {'name': 'EUIPCOH00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 100916797357730.56},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 843867996015.686},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 163167920264.6535},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 49932152089.10855},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 200207420043.34985}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 86760663861603.27,
#           'label': None}],
#         'bw_activity_code': 'cfa79d34d94d122a4fd35786da2c6d4e'},
#        {'name': 'EUNPCOH00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 28686673292268.965},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 239878455018.08765},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 46382217263.171074},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 14193745454.073183},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 56911089165.59103}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 24662641740024.086,
#           'label': None}],
#         'bw_activity_code': 'cfa79d34d94d122a4fd35786da2c6d4e'},
#        {'name': 'EUNPCOLCOH00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 3824731964545.2744},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 5389414204.8928175},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 7655548555.727943},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 8593234835.293129},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 2961160086.578694}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 3573963697860.6523,
#           'label': None}],
#         'bw_activity_code': '068842db6eef205f8d27b326e7e55a0c'}]},
#      {'name': 'Intermittent',
#       'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#         'magnitude': 74408725584720.77},
#        'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 13430217276710.469},
#        'WCP': {'unit': 'cubic meter', 'magnitude': 1427613509098.6272},
#        'FEP': {'unit': 'kg P-Eq', 'magnitude': 32850630593.50198},
#        'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 4778100681586.644}},
#       'output': [{'unit': 'kilowatt_hour',
#         'magnitude': 1565106894388893.8,
#         'label': None}],
#       'children': [{'name': 'EUHYD1_10MW__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 116043910307.42192},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 4706440892.58947},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 570768656.6829221},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 28296328.600967042},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 11048173413.174862}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 26536644764418.934,
#           'label': None}],
#         'bw_activity_code': '3f9af15db6e86e39021de2d013bf26d3'},
#        {'name': 'EUHYD1_10MW101__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 16425316761.248608},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 666168369.1465557},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 80788866.54727137},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 4005174.931022627},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 1563802421.5420866}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 3756102279490.611,
#           'label': None}],
#         'bw_activity_code': '3f9af15db6e86e39021de2d013bf26d3'},
#        {'name': 'EUHYDL1MW__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 18760892129.087105},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 760893265.4018354},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 92276528.51628388},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 4574685.281696727},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 1786165160.0602403}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 4290196086836.5107,
#           'label': None}],
#         'bw_activity_code': '3f9af15db6e86e39021de2d013bf26d3'},
#        {'name': 'EUPVSOL00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 3554429793284.8354},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 1204968891389.4792},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 115680590509.13528},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 1682609281.474248},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 157309871725.71402}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 51508366971217.51,
#           'label': None}],
#         'bw_activity_code': '46ec4bc016881dafa23a3bbc4c11a7e4'},
#        {'name': 'EUPVSOL101__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 29857353378729.434},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 10121787204119.166},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 971721618026.0842},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 14133985712.763561},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 1321409256440.2893}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 432672356484890.06,
#           'label': None}],
#         'bw_activity_code': '46ec4bc016881dafa23a3bbc4c11a7e4'},
#        {'name': 'EUPVSOLAUTOCAGR101__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 20425838472.59148},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 6924458034.154219},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 664768526.4786332},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 9669259.879829193},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 903994794.3914346}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 295997289277.96295,
#           'label': None}],
#         'bw_activity_code': '46ec4bc016881dafa23a3bbc4c11a7e4'},
#        {'name': 'EUPVSOLAUTOCCOM101__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 1209073302752.0159},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 30530520367.468884},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 30480699474.579468},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 701456539.3699206},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 43069403567.01736}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 15684800199174.143,
#           'label': None}],
#         'bw_activity_code': '8b0ca7f94a5fc4975be65b4026151bc0'},
#        {'name': 'EUPVSOLAUTOCIND101__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 163850922431.21506},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 4137428156.1237264},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 4130676538.7079716},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 95059828.68010712},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 5836669693.141703}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 2125569206542.322,
#           'label': None}],
#         'bw_activity_code': '8b0ca7f94a5fc4975be65b4026151bc0'},
#        {'name': 'EUPVSOLAUTOCRSD101__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 2448406650324.962},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 61825142394.65014},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 61724253715.923454},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 1420468760.6609669},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 87216725304.58582}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 31762151251980.797,
#           'label': None}],
#         'bw_activity_code': '8b0ca7f94a5fc4975be65b4026151bc0'},
#        {'name': 'EUPVSOLREPOW101__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 1055791778271.399},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 357918519311.41925},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 34361240330.54846},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 499794664.3312251},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 46726614076.63299}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 15299812775353.46,
#           'label': None}],
#         'bw_activity_code': '46ec4bc016881dafa23a3bbc4c11a7e4'},
#        {'name': 'EUSTMUN00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq', 'magnitude': 0.0},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 0.0},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 0.0},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 0.0},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 0.0}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 3929419405598.1787,
#           'label': None}],
#         'bw_activity_code': '457a9cb15fd86328b0109ec4216b1632'},
#        {'name': 'EUSTOIL00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 12436780539330.203},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 22504343820.69182},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 17003620674.322039},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 158003862.05352795},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 39919542895.72982}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 13288974676024.71,
#           'label': None}],
#         'bw_activity_code': '8512aa7eb21d45b94590bb09716506b8'},
#        {'name': 'EUTHSOL00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 507573307402.8211},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 58895824438.12859},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 2385680439.351264},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 74380391.19204003},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 46070055644.04437}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 9365479725453.904,
#           'label': None}],
#         'bw_activity_code': '19040cdacdbf038e2f6ad59814f7a9ed'},
#        {'name': 'EUTHSOLREPOW101__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 660143273735.5126},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 76599146968.76608},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 3102785100.1356416},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 96738174.08097759},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 59918118052.43283}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 12180621703786.559,
#           'label': None}],
#         'bw_activity_code': '19040cdacdbf038e2f6ad59814f7a9ed'},
#        {'name': 'EUTHSOLSTG101__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 4233384695012.079},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 491217087716.8969},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 19897624464.961643},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 620365186.6756363},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 384244532983.7938}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 78112221326881.12,
#           'label': None}],
#         'bw_activity_code': '19040cdacdbf038e2f6ad59814f7a9ed'},
#        {'name': 'EUTHSOLSTGREPOW101__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 246361155767.77203},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 28586301085.826233},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 1157939122.943179},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 36102054.41531952},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 22361050095.618465}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 4545728419544.8125,
#           'label': None}],
#         'bw_activity_code': '19040cdacdbf038e2f6ad59814f7a9ed'},
#        {'name': 'EUWIN00__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 2673433309980.032},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 186976700237.7092},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 23914884140.50104},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 1149852610.1629934},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 375338269947.43805}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 175380574010788.9,
#           'label': None}],
#         'bw_activity_code': 'ed3da88fc23311ee183e9ffd376de89b'},
#        {'name': 'EUWINOF201__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 858515863774.6807},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 19215934430.733036},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 9484844837.869484},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 348920109.0099758},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 105370482859.04234}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 50440261621185.734,
#           'label': None}],
#         'bw_activity_code': '6ebfe52dc3ef5b4d35bb603b03559023'},
#        {'name': 'EUWINOFREPOW201__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 19102675537.355473},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 427570155.1168011},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 211045504.34593952},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 7763755.9329032255},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 2344578860.100817}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 1122336805198.946,
#           'label': None}],
#         'bw_activity_code': '6ebfe52dc3ef5b4d35bb603b03559023'},
#        {'name': 'EUWINON201__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 4878977260298.825},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 239632990791.93},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 44830833254.773056},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 4388387389.882877},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 707875512921.6293}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 195387295740392.25,
#           'label': None}],
#         'bw_activity_code': '0d48975a3766c13e68cedeb6c24f6f74'},
#        {'name': 'EUWINON501__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 7100638886246.056},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 348750822609.41705},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 65244730796.64155},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 6386656974.615465},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 1030209432328.1567}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 284357674977220.56,
#           'label': None}],
#         'bw_activity_code': '0d48975a3766c13e68cedeb6c24f6f74'},
#        {'name': 'EUWINONREPEXIST101__ELCHIG',
#         'results': {'GWP1000': {'unit': 'kg CO2-Eq',
#           'magnitude': 2333252834171.2085},
#          'LOP': {'unit': 'm2*a crop-Eq', 'magnitude': 163184888155.65393},
#          'WCP': {'unit': 'cubic meter', 'magnitude': 20871839589.578976},
#          'FEP': {'unit': 'kg P-Eq', 'magnitude': 1003539849.5067179},
#          'SOP': {'unit': 'kg Cu-Eq', 'magnitude': 327578428402.1073}},
#         'output': [{'unit': 'kilowatt_hour',
#           'magnitude': 153064308667635.72,
#           'label': None}],
#         'bw_activity_code': 'ed3da88fc23311ee183e9ffd376de89b'}]}]}]}}

# %% [markdown]
# Save the results

# %%
results_dict=exp.result_to_dict()
results_csv = exp.results_to_csv('output.csv')

df = pd.read_csv('output.csv')
df.head()
# Out:
#    level         lvl_0       lvl_1     lvl_2                   lvl_3  \
# 0      0  Energysystem         NaN       NaN                     NaN
# 1      1           NaN  Generation       NaN                     NaN
# 2      2           NaN         NaN  Baseload                     NaN
# 3      3           NaN         NaN       NaN     CHPAGRBGS00__ELCHIG
# 4      3           NaN         NaN       NaN  CHPAGRBGSREP01__ELCHIG
#
#   results_GWP1000_unit  results_GWP1000_magnitude results_LOP_unit  \
# 0            kg CO2-Eq               5.098031e+14     m2*a crop-Eq
# 1            kg CO2-Eq               5.098031e+14     m2*a crop-Eq
# 2            kg CO2-Eq               4.353944e+14     m2*a crop-Eq
# 3            kg CO2-Eq               4.218420e+10     m2*a crop-Eq
# 4            kg CO2-Eq               4.907969e+10     m2*a crop-Eq
#
#    results_LOP_magnitude results_WCP_unit  results_WCP_magnitude  \
# 0           1.771624e+13      cubic meter           6.928428e+12
# 1           1.771624e+13      cubic meter           6.928428e+12
# 2           4.286019e+12      cubic meter           5.500815e+12
# 3           3.772448e+08      cubic meter           1.136056e+07
# 4           4.389098e+08      cubic meter           1.321758e+07
#
#   results_FEP_unit  results_FEP_magnitude results_SOP_unit  \
# 0          kg P-Eq           1.217947e+11         kg Cu-Eq
# 1          kg P-Eq           1.217947e+11         kg Cu-Eq
# 2          kg P-Eq           8.894405e+10         kg Cu-Eq
# 3          kg P-Eq           1.880952e+06         kg Cu-Eq
# 4          kg P-Eq           2.188415e+06         kg Cu-Eq
#
#    results_SOP_magnitude  output_0_unit  output_0_magnitude  output_0_label  \
# 0           6.970625e+12  kilowatt_hour        2.610618e+15             NaN
# 1           6.970625e+12  kilowatt_hour        2.610618e+15             NaN
# 2           2.192524e+12  kilowatt_hour        1.045511e+15             NaN
# 3           6.280294e+07  kilowatt_hour        4.528060e+10             NaN
# 4           7.306880e+07  kilowatt_hour        5.268224e+10             NaN
#
#                    bw_activity_code
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3  4de25bf8baf97e6cdaf2b4d4721a71a4
# 4  4de25bf8baf97e6cdaf2b4d4721a71a4

# %%
from enbios.base.result_select import ResultsSelector
from enbios.base.plot_experiment import bar_plot

# We will only see one scenario
rs = ResultsSelector.get_result_selector(exp)
bar_plot(exp)
rs.base_df
# Out:
#      scenario       GWP1000           LOP           WCP           FEP  \
# 0  def_hydro1  5.098031e+14  1.771624e+13  6.928428e+12  1.217947e+11
#
#             SOP
# 0  6.970625e+12

# %%
from enbios.base.plot_experiment import stacked_bar_plot
for method in range (len(exp.method_names)):
   
    if method > 0:
        stacked_bar_plot(exp, methods=exp.methods[:method], level=2)
    #stacked_bar_plot(exp, methods = exp.methods[:method],level=2)

# %%
stacked_bar_plot(exp, methods=exp.methods[:1], level=3);
# Out:
# C:\Users\altz7\PycharmProjects\ENBIOS4TIMES_\sparks_2\lib\site-packages\enbios\base\plot_experiment.py:87: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
